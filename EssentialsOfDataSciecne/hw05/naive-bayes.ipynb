# %%
import numpy as np
import pandas as pd
import re

# %%
cols = ['polarity','id', 'date', 'query', 'user', 'tweet']

data = pd.read_csv('sentiment.csv',names=cols, encoding='ISO-8859-1')
print('length of data {}'.format(len(data)))
# Out:
# length of data 1600000

# %%
data[:5]
# Out:
#    polarity          id                          date     query  \
# 0         0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1         0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2         0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3         0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4         0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                              tweet
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# Sample the data into a random set of 1% of our data set

# %%
random = data.sample(frac = 0.01)
random
# Out:
#          polarity          id                          date     query  \
# 1465654         4  2064375874  Sun Jun 07 06:05:30 PDT 2009  NO_QUERY
# 143745          0  1881800500  Fri May 22 05:35:21 PDT 2009  NO_QUERY
# 1215916         4  1989591306  Mon Jun 01 02:05:52 PDT 2009  NO_QUERY
# 1481839         4  2067144985  Sun Jun 07 11:49:44 PDT 2009  NO_QUERY
# 66450           0  1691813413  Sun May 03 18:39:52 PDT 2009  NO_QUERY
# ...           ...         ...                           ...       ...
# 785955          0  2324552163  Thu Jun 25 03:27:00 PDT 2009  NO_QUERY
# 339404          0  2014636897  Wed Jun 03 02:11:13 PDT 2009  NO_QUERY
# 418113          0  2061690969  Sat Jun 06 21:24:13 PDT 2009  NO_QUERY
# 1200850         4  1985574369  Sun May 31 17:21:59 PDT 2009  NO_QUERY
# 668476          0  2245948202  Fri Jun 19 16:52:27 PDT 2009  NO_QUERY
#
#                    user                                              tweet
# 1465654  computergrl123  @billyraycyrus what part of ireland are/were y...
# 143745    gsdadventures    @sarahdessen we still have our winter coats on
# 1215916         kopigao                          Threadless Tees $5 sale!
# 1481839    tiger_lily09                           gone swimming with sebs
# 66450          Samrose4    @KimKardashian im at work and im gonna miss it
# ...                 ...                                                ...
# 785955        injenious  @WAHMBizbuilder Yes  &amp; stand around in the...
# 339404    unsaidthingsx                 why are planetickets so expensive
# 418113       Monica2112  @timothyh2o  btw, i'm getting tire of the jobr...
# 1200850  shrimponbarbie  Yay for everyone who's down with the blog/trac...
# 668476      lizzieed0LL  @hellaelisa I'm in LA forthe weekend sorry  I ...
#
# [16000 rows x 6 columns]

# %% [markdown]
# Dropping columns to clean it up

# %%
new_data = random.drop(columns = ['id', 'date', 'query', 'user'])
new_data
# Out:
#          polarity                                              tweet
# 1465654         4  @billyraycyrus what part of ireland are/were y...
# 143745          0    @sarahdessen we still have our winter coats on
# 1215916         4                          Threadless Tees $5 sale!
# 1481839         4                           gone swimming with sebs
# 66450           0    @KimKardashian im at work and im gonna miss it
# ...           ...                                                ...
# 785955          0  @WAHMBizbuilder Yes  &amp; stand around in the...
# 339404          0                 why are planetickets so expensive
# 418113          0  @timothyh2o  btw, i'm getting tire of the jobr...
# 1200850         4  Yay for everyone who's down with the blog/trac...
# 668476          0  @hellaelisa I'm in LA forthe weekend sorry  I ...
#
# [16000 rows x 2 columns]

# %%
new_data['polarity'] = new_data['polarity'].apply(lambda x: "pos" if x == 4 else "neg")
new_data
# Out:
#         polarity                                              tweet
# 1465654      pos  @billyraycyrus what part of ireland are/were y...
# 143745       neg    @sarahdessen we still have our winter coats on
# 1215916      pos                          Threadless Tees $5 sale!
# 1481839      pos                           gone swimming with sebs
# 66450        neg    @KimKardashian im at work and im gonna miss it
# ...          ...                                                ...
# 785955       neg  @WAHMBizbuilder Yes  &amp; stand around in the...
# 339404       neg                 why are planetickets so expensive
# 418113       neg  @timothyh2o  btw, i'm getting tire of the jobr...
# 1200850      pos  Yay for everyone who's down with the blog/trac...
# 668476       neg  @hellaelisa I'm in LA forthe weekend sorry  I ...
#
# [16000 rows x 2 columns]

# %%
new_data['splittweet'] = new_data['tweet'].apply(lambda x: x.split())

# %%
new_data
# Out:
#         polarity                                              tweet  \
# 1465654      pos  @billyraycyrus what part of ireland are/were y...
# 143745       neg    @sarahdessen we still have our winter coats on
# 1215916      pos                          Threadless Tees $5 sale!
# 1481839      pos                           gone swimming with sebs
# 66450        neg    @KimKardashian im at work and im gonna miss it
# ...          ...                                                ...
# 785955       neg  @WAHMBizbuilder Yes  &amp; stand around in the...
# 339404       neg                 why are planetickets so expensive
# 418113       neg  @timothyh2o  btw, i'm getting tire of the jobr...
# 1200850      pos  Yay for everyone who's down with the blog/trac...
# 668476       neg  @hellaelisa I'm in LA forthe weekend sorry  I ...
#
#                                                 splittweet
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [Threadless, Tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@KimKardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@WAHMBizbuilder, Yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [Yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, I'm, in, LA, forthe, weekend, so...
#
# [16000 rows x 3 columns]

# %%
vocabulary = [w for s in new_data.splittweet for w in s ]
len(vocabulary)
# Out:
# 209045

# %%
len(set(vocabulary))
# Out:
# 42547

# %% [markdown]
# Making the train and test sets

# %%
test = new_data.sample(frac=0.1)
train = new_data[~new_data.index.isin(test.index)]

# %%
from collections import Counter as ctr

p_t_estimate = ctr(train.polarity)
p_t_total = len(train)

# %%
p_t_estimate['neg']
# Out:
# 7148

# %%
def Pt(T):
    return p_t_estimate[T] / p_t_total

# %%
Pt('pos'), Pt('neg')
# Out:
# (0.5036111111111111, 0.4963888888888889)

# %% [markdown]
# ##### Estimate P(W)

# %%
words = [w for s in train.splittweet for w in s]
p_w_estimate = ctr(words)
p_w_total = len(words)

# %%
smoother = 0.00001
def Pw(W):
    if W not in p_w_estimate: return smoother
    return p_w_estimate[W] / p_w_total

# %%
Pw('hungry')
# Out:
# 6.38073867684749e-05

# %%
np.sum([Pw(w) for w in set(words)])
# Out:
# 1.0

# %% [markdown]
# ##### Estimate P(W|T)

# %%
p_w_t_estimate = {}
p_w_t_totals = {}

for p in set(train.polarity):
    sub_frame = train[train.polarity == p]
    sub_words = [w for s in sub_frame.splittweet for w in s]
    p_w_t_estimate[p] = ctr(sub_words)
    p_w_t_totals[p] = len(sub_words)

# %%
def Pwt(W, T):
    if W not in p_w_t_estimate[T]: return smoother
    return p_w_t_estimate[T][W] / p_w_t_totals[T]

# %%
Pwt('the','pos')
# Out:
# 0.02367064642861051

# %% [markdown]
# ##### Bayes Therom

# %%
def Ptw(T, W):
    return Pwt(W, T) * Pt(T) / Pw(W)

# %%
def Pe(E):
    result = {}
    for p in set(train.polarity):
        result[p] = np.prod([Ptw(p, word) for word in E])
    return result

# %%
Pe(['the', 'river', 'is', 'long'])
# Out:
# {'pos': 0.04656821592662114, 'neg': 0.07364525102898878}

# %%
len(test)
# Out:
# 1600

# %%
test['result'] = test.splittweet.apply(Pe)
test
# Out:
#         polarity                                              tweet  \
# 1467193      pos                    watching the French Open final
# 283148       neg  Stuck in doctor's waiting room. Had to check i...
# 1482033      pos                             Fisher cats are great
# 1096179      pos  Time for me to go to bed. Love the idea I can ...
# 384967       neg              It's my birthday! Time to go to work
# ...          ...                                                ...
# 300022       neg  I...won't be able to play the Sims 3 without a...
# 649660       neg                                  Eating papayas
# 413431       neg  @the_sandra Ahh it was just on, unf  lol, im s...
# 813635       pos  p.s. @TobyDiva is one of the smart folks - I w...
# 1509931      pos             @AndreasChoice  Goodnight Chica! hehe
#
#                                                 splittweet  \
# 1467193               [watching, the, French, Open, final]
# 283148   [Stuck, in, doctor's, waiting, room., Had, to,...
# 1482033                         [Fisher, cats, are, great]
# 1096179  [Time, for, me, to, go, to, bed., Love, the, i...
# 384967       [It's, my, birthday!, Time, to, go, to, work]
# ...                                                    ...
# 300022   [I...won't, be, able, to, play, the, Sims, 3, ...
# 649660                                   [Eating, papayas]
# 413431   [@the_sandra, Ahh, it, was, just, on,, unf, lo...
# 813635   [p.s., @TobyDiva, is, one, of, the, smart, fol...
# 1509931          [@AndreasChoice, Goodnight, Chica!, hehe]
#
#                                                     result
# 1467193  {'pos': 0.055650114983389336, 'neg': 0.0071663...
# 283148   {'pos': 1.8421075804466763e-08, 'neg': 7.54635...
# 1482033  {'pos': 0.07240285006544905, 'neg': 0.02574631...
# 1096179  {'pos': 1.801786330307612e-08, 'neg': 2.681237...
# 384967   {'pos': 0.0013991281347556215, 'neg': 0.004804...
# ...                                                    ...
# 300022   {'pos': 5.0881616055200474e-05, 'neg': 0.00057...
# 649660   {'pos': 0.3914855680140972, 'neg': 0.119819172...
# 413431   {'pos': 4.040806044620598e-05, 'neg': 0.000566...
# 813635   {'pos': 6.568612896701607e-06, 'neg': 5.483243...
# 1509931  {'pos': 0.16505025380665264, 'neg': 0.01104356...
#
# [1600 rows x 4 columns]

# %%
test['top'] = test.result.apply(lambda x:max(x, key=x.get))
test
# Out:
#         polarity                                              tweet  \
# 1467193      pos                    watching the French Open final
# 283148       neg  Stuck in doctor's waiting room. Had to check i...
# 1482033      pos                             Fisher cats are great
# 1096179      pos  Time for me to go to bed. Love the idea I can ...
# 384967       neg              It's my birthday! Time to go to work
# ...          ...                                                ...
# 300022       neg  I...won't be able to play the Sims 3 without a...
# 649660       neg                                  Eating papayas
# 413431       neg  @the_sandra Ahh it was just on, unf  lol, im s...
# 813635       pos  p.s. @TobyDiva is one of the smart folks - I w...
# 1509931      pos             @AndreasChoice  Goodnight Chica! hehe
#
#                                                 splittweet  \
# 1467193               [watching, the, French, Open, final]
# 283148   [Stuck, in, doctor's, waiting, room., Had, to,...
# 1482033                         [Fisher, cats, are, great]
# 1096179  [Time, for, me, to, go, to, bed., Love, the, i...
# 384967       [It's, my, birthday!, Time, to, go, to, work]
# ...                                                    ...
# 300022   [I...won't, be, able, to, play, the, Sims, 3, ...
# 649660                                   [Eating, papayas]
# 413431   [@the_sandra, Ahh, it, was, just, on,, unf, lo...
# 813635   [p.s., @TobyDiva, is, one, of, the, smart, fol...
# 1509931          [@AndreasChoice, Goodnight, Chica!, hehe]
#
#                                                     result  top
# 1467193  {'pos': 0.055650114983389336, 'neg': 0.0071663...  pos
# 283148   {'pos': 1.8421075804466763e-08, 'neg': 7.54635...  neg
# 1482033  {'pos': 0.07240285006544905, 'neg': 0.02574631...  pos
# 1096179  {'pos': 1.801786330307612e-08, 'neg': 2.681237...  neg
# 384967   {'pos': 0.0013991281347556215, 'neg': 0.004804...  neg
# ...                                                    ...  ...
# 300022   {'pos': 5.0881616055200474e-05, 'neg': 0.00057...  neg
# 649660   {'pos': 0.3914855680140972, 'neg': 0.119819172...  pos
# 413431   {'pos': 4.040806044620598e-05, 'neg': 0.000566...  neg
# 813635   {'pos': 6.568612896701607e-06, 'neg': 5.483243...  pos
# 1509931  {'pos': 0.16505025380665264, 'neg': 0.01104356...  pos
#
# [1600 rows x 5 columns]

# %%
sum(test.polarity == test.top) / len(test)
# Out:
# 0.71

# %% [markdown]
# ## Comparing Results

# %% [markdown]
# #### Lowercase values

# %%
new_data['lowercase'] = new_data['tweet'].apply(lambda x: [i.lower() for i in x.split()])
new_data
# Out:
#         polarity                                              tweet  \
# 1465654      pos  @billyraycyrus what part of ireland are/were y...
# 143745       neg    @sarahdessen we still have our winter coats on
# 1215916      pos                          Threadless Tees $5 sale!
# 1481839      pos                           gone swimming with sebs
# 66450        neg    @KimKardashian im at work and im gonna miss it
# ...          ...                                                ...
# 785955       neg  @WAHMBizbuilder Yes  &amp; stand around in the...
# 339404       neg                 why are planetickets so expensive
# 418113       neg  @timothyh2o  btw, i'm getting tire of the jobr...
# 1200850      pos  Yay for everyone who's down with the blog/trac...
# 668476       neg  @hellaelisa I'm in LA forthe weekend sorry  I ...
#
#                                                 splittweet  \
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [Threadless, Tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@KimKardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@WAHMBizbuilder, Yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [Yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, I'm, in, LA, forthe, weekend, so...
#
#                                                  lowercase
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [threadless, tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@kimkardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@wahmbizbuilder, yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, i'm, in, la, forthe, weekend, so...
#
# [16000 rows x 4 columns]

# %%
test_lower = new_data.sample(frac=0.1)
train_lower = new_data[~new_data.index.isin(test_lower.index)]

# %%
words = [w for s in train_lower.lowercase for w in s]
p_w_estimate = ctr(words)
p_w_total = len(words)

# %%
##Checking to see if it works for row 1207318 NKOTB is capitalized then in lowecase is isn't so its probability is 0
Pw('NKOTB')
# Out:
# 1e-05

# %%
p_w_t_estimate = {}
p_w_t_totals = {}

for l in set(train_lower.polarity):
    sub_frame = train_lower[train_lower.polarity == l]
    sub_words = [w for s in sub_frame.lowercase for w in s]
    p_w_t_estimate[l] = ctr(sub_words)
    p_w_t_totals[l] = len(sub_words)

# %%
def PwtL(W, T):
    if W not in p_w_t_estimate[T]: return smoother
    return p_w_t_estimate[T][W] / p_w_t_totals[T]

# %%
##Checking to see if it works for row 720998 MO is capitalized then in lowecase is isn't so its probability is 0
PwtL('NKOTB','neg')
# Out:
# 1e-05

# %%
def PtwL(T, W):
    return PwtL(W, T) * Pt(T) / Pw(W)

# %%
def Pe(E):
    result = {}
    for p in set(train_lower.polarity):
        result[p] = np.prod([PtwL(p, word) for word in E])
    return result

# %%
Pe(['the', 'river', 'is', 'long'])
# Out:
# {'pos': 0.05730801481486517, 'neg': 0.13674488406356597}

# %%
test_lower['result'] = test_lower.lowercase.apply(Pe)
test_lower['top'] = test_lower.result.apply(lambda x:max(x, key=x.get))
test_lower
# Out:
#         polarity                                              tweet  \
# 787982       neg  @keelybin it only gets worse  when ya get ya o...
# 1227707      pos  @ashashbaby or the ones u dont wanna hang out ...
# 400119       neg  @FDoTNiTTi hell nowhere. its fckn boring.n I w...
# 1387755      pos  is getting ready for 8.......miles that is!  T...
# 253611       neg  @rejectedmoments aww are you okay hun, you see...
# ...          ...                                                ...
# 280622       neg  is at home drinking coffee and wishing Marshal...
# 598611       neg  Don't know why i made twitter, don't even use it
# 46676        neg                   Hasn't felt this rough in ages.
# 459450       neg  @chips99 omg I WAS NOT expecting the ending!! ...
# 1104729      pos                 @Beeyezzy come on! when u coming?
#
#                                                 splittweet  \
# 787982   [@keelybin, it, only, gets, worse, when, ya, g...
# 1227707  [@ashashbaby, or, the, ones, u, dont, wanna, h...
# 400119   [@FDoTNiTTi, hell, nowhere., its, fckn, boring...
# 1387755  [is, getting, ready, for, 8.......miles, that,...
# 253611   [@rejectedmoments, aww, are, you, okay, hun,, ...
# ...                                                    ...
# 280622   [is, at, home, drinking, coffee, and, wishing,...
# 598611   [Don't, know, why, i, made, twitter,, don't, e...
# 46676               [Hasn't, felt, this, rough, in, ages.]
# 459450   [@chips99, omg, I, WAS, NOT, expecting, the, e...
# 1104729           [@Beeyezzy, come, on!, when, u, coming?]
#
#                                                  lowercase  \
# 787982   [@keelybin, it, only, gets, worse, when, ya, g...
# 1227707  [@ashashbaby, or, the, ones, u, dont, wanna, h...
# 400119   [@fdotnitti, hell, nowhere., its, fckn, boring...
# 1387755  [is, getting, ready, for, 8.......miles, that,...
# 253611   [@rejectedmoments, aww, are, you, okay, hun,, ...
# ...                                                    ...
# 280622   [is, at, home, drinking, coffee, and, wishing,...
# 598611   [don't, know, why, i, made, twitter,, don't, e...
# 46676               [hasn't, felt, this, rough, in, ages.]
# 459450   [@chips99, omg, i, was, not, expecting, the, e...
# 1104729           [@beeyezzy, come, on!, when, u, coming?]
#
#                                                     result  top
# 787982   {'pos': 0.0007575328169419091, 'neg': 0.001582...  neg
# 1227707  {'pos': 0.00046899492279994077, 'neg': 0.00070...  neg
# 400119   {'pos': 0.0001002709054411572, 'neg': 0.020197...  neg
# 1387755  {'pos': 0.007700137282766419, 'neg': 0.0018924...  pos
# 253611   {'pos': 0.0039206022071749305, 'neg': 0.000493...  pos
# ...                                                    ...  ...
# 280622   {'pos': 0.00010924530893752148, 'neg': 0.00147...  neg
# 598611   {'pos': 0.004098271293386389, 'neg': 0.0185327...  neg
# 46676    {'pos': 0.012159590507974606, 'neg': 0.0948742...  neg
# 459450   {'pos': 0.0008391647218349451, 'neg': 0.321539...  neg
# 1104729  {'pos': 0.02729268276142641, 'neg': 0.00826432...  pos
#
# [1600 rows x 6 columns]

# %%
sum(test_lower.polarity == test_lower.top) / len(test_lower)
# Out:
# 0.7275

# %% [markdown]
# #### HashTag values

# %%
new_data['hashtag'] = new_data['tweet'].apply(lambda x: [i.replace('#', '') for i in x.split()])
new_data
# Out:
#         polarity                                              tweet  \
# 1465654      pos  @billyraycyrus what part of ireland are/were y...
# 143745       neg    @sarahdessen we still have our winter coats on
# 1215916      pos                          Threadless Tees $5 sale!
# 1481839      pos                           gone swimming with sebs
# 66450        neg    @KimKardashian im at work and im gonna miss it
# ...          ...                                                ...
# 785955       neg  @WAHMBizbuilder Yes  &amp; stand around in the...
# 339404       neg                 why are planetickets so expensive
# 418113       neg  @timothyh2o  btw, i'm getting tire of the jobr...
# 1200850      pos  Yay for everyone who's down with the blog/trac...
# 668476       neg  @hellaelisa I'm in LA forthe weekend sorry  I ...
#
#                                                 splittweet  \
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [Threadless, Tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@KimKardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@WAHMBizbuilder, Yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [Yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, I'm, in, LA, forthe, weekend, so...
#
#                                                  lowercase  \
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [threadless, tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@kimkardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@wahmbizbuilder, yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, i'm, in, la, forthe, weekend, so...
#
#                                                    hashtag
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [Threadless, Tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@KimKardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@WAHMBizbuilder, Yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [Yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, I'm, in, LA, forthe, weekend, so...
#
# [16000 rows x 5 columns]

# %%
test_hash = new_data.sample(frac=0.1)
train_hash = new_data[~new_data.index.isin(test_hash.index)]

# %%
words = [w for s in train_hash.hashtag for w in s]
p_w_estimate = ctr(words)
p_w_total = len(words)

# %%
p_w_t_estimate = {}
p_w_t_totals = {}

for l in set(train_hash.polarity):
    sub_frame = train_hash[train_hash.polarity == l]
    sub_words = [w for s in sub_frame.hashtag for w in s]
    p_w_t_estimate[l] = ctr(sub_words)
    p_w_t_totals[l] = len(sub_words)

# %%
def PwtH(W, T):
    if W not in p_w_t_estimate[T]: return smoother
    return p_w_t_estimate[T][W] / p_w_t_totals[T]

# %%
def PtwH(T, W):
    return PwtH(W, T) * Pt(T) / Pw(W)

# %%
def Pe(E):
    result = {}
    for p in set(train_hash.polarity):
        result[p] = np.prod([PtwH(p, word) for word in E])
    return result

# %%
test_hash['result'] = test_hash.hashtag.apply(Pe)
test_hash['top'] = test_hash.result.apply(lambda x:max(x, key=x.get))
test_hash
# Out:
#         polarity                                              tweet  \
# 1593872      pos  is headed back home to make dinner to when my ...
# 561450       neg  Off To The Showers Getting Ready For Work....B...
# 1427262      pos  @snshyne  What a darling little pup. Just look...
# 632979       neg  Today was a bad day, and I feel like crap beca...
# 1521421      pos  hi @ all.... how you been?.... hope youÂ´re fi...
# ...          ...                                                ...
# 40010        neg  @awesomepam That /would/ be weird to see. I ha...
# 910819       pos  @BigGuitarStore I'll drink to that  #shotdrink...
# 461635       neg              please..everything to the way it was
# 742176       neg             @Danielle_Jane14 ugh that's no fun  :/
# 348822       neg  @longpour indeed  still don't know if I'm sad....
#
#                                                 splittweet  \
# 1593872  [is, headed, back, home, to, make, dinner, to,...
# 561450   [Off, To, The, Showers, Getting, Ready, For, W...
# 1427262  [@snshyne, What, a, darling, little, pup., Jus...
# 632979   [Today, was, a, bad, day,, and, I, feel, like,...
# 1521421  [hi, @, all...., how, you, been?...., hope, yo...
# ...                                                    ...
# 40010    [@awesomepam, That, /would/, be, weird, to, se...
# 910819   [@BigGuitarStore, I'll, drink, to, that, #shot...
# 461635         [please..everything, to, the, way, it, was]
# 742176        [@Danielle_Jane14, ugh, that's, no, fun, :/]
# 348822   [@longpour, indeed, still, don't, know, if, I'...
#
#                                                  lowercase  \
# 1593872  [is, headed, back, home, to, make, dinner, to,...
# 561450   [off, to, the, showers, getting, ready, for, w...
# 1427262  [@snshyne, what, a, darling, little, pup., jus...
# 632979   [today, was, a, bad, day,, and, i, feel, like,...
# 1521421  [hi, @, all...., how, you, been?...., hope, yo...
# ...                                                    ...
# 40010    [@awesomepam, that, /would/, be, weird, to, se...
# 910819   [@bigguitarstore, i'll, drink, to, that, #shot...
# 461635         [please..everything, to, the, way, it, was]
# 742176        [@danielle_jane14, ugh, that's, no, fun, :/]
# 348822   [@longpour, indeed, still, don't, know, if, i'...
#
#                                                    hashtag  \
# 1593872  [is, headed, back, home, to, make, dinner, to,...
# 561450   [Off, To, The, Showers, Getting, Ready, For, W...
# 1427262  [@snshyne, What, a, darling, little, pup., Jus...
# 632979   [Today, was, a, bad, day,, and, I, feel, like,...
# 1521421  [hi, @, all...., how, you, been?...., hope, yo...
# ...                                                    ...
# 40010    [@awesomepam, That, /would/, be, weird, to, se...
# 910819   [@BigGuitarStore, I'll, drink, to, that, shotd...
# 461635         [please..everything, to, the, way, it, was]
# 742176        [@Danielle_Jane14, ugh, that's, no, fun, :/]
# 348822   [@longpour, indeed, still, don't, know, if, I'...
#
#                                                     result  top
# 1593872  {'pos': 1.6195479782266468e-07, 'neg': 2.39576...  pos
# 561450   {'pos': 0.018828337309575085, 'neg': 0.0004353...  pos
# 1427262  {'pos': 5.138225890819373e-06, 'neg': 2.238416...  pos
# 632979   {'pos': 6.275123344894387e-06, 'neg': 0.000447...  neg
# 1521421  {'pos': 0.0009872888577810547, 'neg': 0.000588...  pos
# ...                                                    ...  ...
# 40010    {'pos': 0.000175477979527997, 'neg': 0.0019795...  neg
# 910819   {'pos': 0.014334913519071906, 'neg': 0.0149747...  neg
# 461635   {'pos': 0.014548416849423046, 'neg': 0.0164588...  neg
# 742176   {'pos': 0.005809600973056252, 'neg': 0.0150599...  neg
# 348822   {'pos': 9.895124488450043e-08, 'neg': 2.240777...  neg
#
# [1600 rows x 7 columns]

# %%
sum(test_hash.polarity == test_hash.top) / len(test_hash)
# Out:
# 0.725625

# %% [markdown]
# #### Stem values

# %%
import nltk
from nltk.stem import PorterStemmer
ps=PorterStemmer()
ps.stem('writing')
#split and step through each word, in line for loops
new_data['stem'] = new_data['lowercase'].apply(lambda x: [ps.stem(i) for i in x])
new_data['join'] = new_data['stem'].apply(lambda x: ' '.join(x))
new_data
# Out:
#         polarity                                              tweet  \
# 1465654      pos  @billyraycyrus what part of ireland are/were y...
# 143745       neg    @sarahdessen we still have our winter coats on
# 1215916      pos                          Threadless Tees $5 sale!
# 1481839      pos                           gone swimming with sebs
# 66450        neg    @KimKardashian im at work and im gonna miss it
# ...          ...                                                ...
# 785955       neg  @WAHMBizbuilder Yes  &amp; stand around in the...
# 339404       neg                 why are planetickets so expensive
# 418113       neg  @timothyh2o  btw, i'm getting tire of the jobr...
# 1200850      pos  Yay for everyone who's down with the blog/trac...
# 668476       neg  @hellaelisa I'm in LA forthe weekend sorry  I ...
#
#                                                 splittweet  \
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [Threadless, Tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@KimKardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@WAHMBizbuilder, Yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [Yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, I'm, in, LA, forthe, weekend, so...
#
#                                                  lowercase  \
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [threadless, tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@kimkardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@wahmbizbuilder, yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, i'm, in, la, forthe, weekend, so...
#
#                                                    hashtag  \
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [Threadless, Tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@KimKardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@WAHMBizbuilder, Yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [Yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, I'm, in, LA, forthe, weekend, so...
#
#                                                       stem  \
# 1465654  [@billyraycyru, what, part, of, ireland, are/w...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                       [threadless, tee, $5, sale!]
# 1481839                            [gone, swim, with, seb]
# 66450    [@kimkardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@wahmbizbuild, ye, &amp;, stand, around, in, ...
# 339404                 [whi, are, planeticket, so, expens]
# 418113   [@timothyh2o, btw,, i'm, get, tire, of, the, j...
# 1200850  [yay, for, everyon, who', down, with, the, blo...
# 668476   [@hellaelisa, i'm, in, la, forth, weekend, sor...
#
#                                                       join
# 1465654  @billyraycyru what part of ireland are/wer you...
# 143745       @sarahdessen we still have our winter coat on
# 1215916                            threadless tee $5 sale!
# 1481839                                 gone swim with seb
# 66450       @kimkardashian im at work and im gonna miss it
# ...                                                    ...
# 785955   @wahmbizbuild ye &amp; stand around in the kit...
# 339404                       whi are planeticket so expens
# 418113   @timothyh2o btw, i'm get tire of the jobros. l...
# 1200850  yay for everyon who' down with the blog/track ...
# 668476   @hellaelisa i'm in la forth weekend sorri i wi...
#
# [16000 rows x 7 columns]

# %%
test_stem = new_data.sample(frac=0.1)
train_stem = new_data[~new_data.index.isin(test_stem.index)]

# %%
words = [w for s in train_stem.stem for w in s]
p_w_estimate = ctr(words)
p_w_total = len(words)

p_w_t_estimate = {}
p_w_t_totals = {}

for l in set(train_stem.polarity):
    sub_frame = train_stem[train_stem.polarity == l]
    sub_words = [w for s in sub_frame.stem for w in s]
    p_w_t_estimate[l] = ctr(sub_words)
    p_w_t_totals[l] = len(sub_words)

# %%
def PwtS(W, T):
    if W not in p_w_t_estimate[T]: return smoother
    return p_w_t_estimate[T][W] / p_w_t_totals[T]

# %%
def PtwS(T, W):
    return PwtS(W, T) * Pt(T) / Pw(W)

# %%
def Pe(E):
    result = {}
    for p in set(train_stem.polarity):
        result[p] = np.prod([PtwS(p, word) for word in E])
    return result

# %%
test_stem['result'] = test_stem.stem.apply(Pe)
test_stem['top'] = test_stem.result.apply(lambda x:max(x, key=x.get))
test_stem
# Out:
#         polarity                                              tweet  \
# 424179       neg  is going to #vote and then drive up to #Bonn ....
# 882724       pos  @Bytorsnowdog haha I guess I'll have to.  I th...
# 1372708      pos  @jonasbrothers http://twitpic.com/6q1om - ooh ...
# 815556       pos  @mpilatow - The consequences of SEO would alwa...
# 770071       neg     @CarlisleRCullen yes but no time for baseball
# ...          ...                                                ...
# 47032        neg  New Dollhouse episode in my line-up, I can't W...
# 905467       pos  @kittyfisher Are they both still talking to yo...
# 117863       neg  Can't find any super-duper nice Twitter app fo...
# 135263       neg  Ugh tired as fuh driving around pines. Tossed ...
# 1250288      pos  @joanvaughan Lol that's a new one! Yay! Steely...
#
#                                                 splittweet  \
# 424179   [is, going, to, #vote, and, then, drive, up, t...
# 882724   [@Bytorsnowdog, haha, I, guess, I'll, have, to...
# 1372708  [@jonasbrothers, http://twitpic.com/6q1om, -, ...
# 815556   [@mpilatow, -, The, consequences, of, SEO, wou...
# 770071   [@CarlisleRCullen, yes, but, no, time, for, ba...
# ...                                                    ...
# 47032    [New, Dollhouse, episode, in, my, line-up,, I,...
# 905467   [@kittyfisher, Are, they, both, still, talking...
# 117863   [Can't, find, any, super-duper, nice, Twitter,...
# 135263   [Ugh, tired, as, fuh, driving, around, pines.,...
# 1250288  [@joanvaughan, Lol, that's, a, new, one!, Yay!...
#
#                                                  lowercase  \
# 424179   [is, going, to, #vote, and, then, drive, up, t...
# 882724   [@bytorsnowdog, haha, i, guess, i'll, have, to...
# 1372708  [@jonasbrothers, http://twitpic.com/6q1om, -, ...
# 815556   [@mpilatow, -, the, consequences, of, seo, wou...
# 770071   [@carlislercullen, yes, but, no, time, for, ba...
# ...                                                    ...
# 47032    [new, dollhouse, episode, in, my, line-up,, i,...
# 905467   [@kittyfisher, are, they, both, still, talking...
# 117863   [can't, find, any, super-duper, nice, twitter,...
# 135263   [ugh, tired, as, fuh, driving, around, pines.,...
# 1250288  [@joanvaughan, lol, that's, a, new, one!, yay!...
#
#                                                    hashtag  \
# 424179   [is, going, to, vote, and, then, drive, up, to...
# 882724   [@Bytorsnowdog, haha, I, guess, I'll, have, to...
# 1372708  [@jonasbrothers, http://twitpic.com/6q1om, -, ...
# 815556   [@mpilatow, -, The, consequences, of, SEO, wou...
# 770071   [@CarlisleRCullen, yes, but, no, time, for, ba...
# ...                                                    ...
# 47032    [New, Dollhouse, episode, in, my, line-up,, I,...
# 905467   [@kittyfisher, Are, they, both, still, talking...
# 117863   [Can't, find, any, super-duper, nice, Twitter,...
# 135263   [Ugh, tired, as, fuh, driving, around, pines.,...
# 1250288  [@joanvaughan, Lol, that's, a, new, one!, Yay!...
#
#                                                       stem  \
# 424179   [is, go, to, #vote, and, then, drive, up, to, ...
# 882724   [@bytorsnowdog, haha, i, guess, i'll, have, to...
# 1372708  [@jonasbroth, http://twitpic.com/6q1om, -, ooh...
# 815556   [@mpilatow, -, the, consequ, of, seo, would, a...
# 770071   [@carlislercullen, ye, but, no, time, for, bas...
# ...                                                    ...
# 47032    [new, dollhous, episod, in, my, line-up,, i, c...
# 905467   [@kittyfish, are, they, both, still, talk, to,...
# 117863   [can't, find, ani, super-dup, nice, twitter, a...
# 135263   [ugh, tire, as, fuh, drive, around, pines., to...
# 1250288  [@joanvaughan, lol, that', a, new, one!, yay!,...
#
#                                                       join  \
# 424179   is go to #vote and then drive up to #bonn ... ...
# 882724   @bytorsnowdog haha i guess i'll have to. i thi...
# 1372708  @jonasbroth http://twitpic.com/6q1om - ooh so ...
# 815556   @mpilatow - the consequ of seo would alway be ...
# 770071         @carlislercullen ye but no time for basebal
# ...                                                    ...
# 47032    new dollhous episod in my line-up, i can't wai...
# 905467    @kittyfish are they both still talk to you then?
# 117863   can't find ani super-dup nice twitter app for ...
# 135263   ugh tire as fuh drive around pines. toss and t...
# 1250288  @joanvaughan lol that' a new one! yay! steely-...
#
#                                                     result  top
# 424179   {'pos': 8.310360091009599e-07, 'neg': 0.000177...  neg
# 882724   {'pos': 3.756645294511516e-07, 'neg': 8.892028...  neg
# 1372708  {'pos': 0.09017528702834415, 'neg': 0.00575511...  pos
# 815556   {'pos': 4.790001716863826e-07, 'neg': 2.906082...  neg
# 770071   {'pos': 0.0051875890176379886, 'neg': 0.008083...  neg
# ...                                                    ...  ...
# 47032    {'pos': 1.4600789172049735e-05, 'neg': 2.06209...  neg
# 905467   {'pos': 0.00229742425534489, 'neg': 0.00124466...  pos
# 117863   {'pos': 0.0007006699596664662, 'neg': 0.000775...  neg
# 135263   {'pos': 2.8672081715784815e-07, 'neg': 3.51485...  neg
# 1250288  {'pos': 0.0032176224674916255, 'neg': 2.994235...  pos
#
# [1600 rows x 9 columns]

# %%
sum(test_stem.polarity == test_stem.top) / len(test_stem)
# Out:
# 0.71875

# %% [markdown]
# ## Open Ended

# %% [markdown]
# #### Using Numbers

# %%
new_data['numbers'] = new_data['splittweet'].apply(lambda x: [i == "NaN" for i in x if not i.isdigit()])
new_data
# Out:
#         polarity                                              tweet  \
# 1465654      pos  @billyraycyrus what part of ireland are/were y...
# 143745       neg    @sarahdessen we still have our winter coats on
# 1215916      pos                          Threadless Tees $5 sale!
# 1481839      pos                           gone swimming with sebs
# 66450        neg    @KimKardashian im at work and im gonna miss it
# ...          ...                                                ...
# 785955       neg  @WAHMBizbuilder Yes  &amp; stand around in the...
# 339404       neg                 why are planetickets so expensive
# 418113       neg  @timothyh2o  btw, i'm getting tire of the jobr...
# 1200850      pos  Yay for everyone who's down with the blog/trac...
# 668476       neg  @hellaelisa I'm in LA forthe weekend sorry  I ...
#
#                                                 splittweet  \
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [Threadless, Tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@KimKardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@WAHMBizbuilder, Yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [Yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, I'm, in, LA, forthe, weekend, so...
#
#                                                  lowercase  \
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [threadless, tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@kimkardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@wahmbizbuilder, yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, i'm, in, la, forthe, weekend, so...
#
#                                                    hashtag  \
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [Threadless, Tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@KimKardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@WAHMBizbuilder, Yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [Yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, I'm, in, LA, forthe, weekend, so...
#
#                                                       stem  \
# 1465654  [@billyraycyru, what, part, of, ireland, are/w...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                       [threadless, tee, $5, sale!]
# 1481839                            [gone, swim, with, seb]
# 66450    [@kimkardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@wahmbizbuild, ye, &amp;, stand, around, in, ...
# 339404                 [whi, are, planeticket, so, expens]
# 418113   [@timothyh2o, btw,, i'm, get, tire, of, the, j...
# 1200850  [yay, for, everyon, who', down, with, the, blo...
# 668476   [@hellaelisa, i'm, in, la, forth, weekend, sor...
#
#                                                       join  \
# 1465654  @billyraycyru what part of ireland are/wer you...
# 143745       @sarahdessen we still have our winter coat on
# 1215916                            threadless tee $5 sale!
# 1481839                                 gone swim with seb
# 66450       @kimkardashian im at work and im gonna miss it
# ...                                                    ...
# 785955   @wahmbizbuild ye &amp; stand around in the kit...
# 339404                       whi are planeticket so expens
# 418113   @timothyh2o btw, i'm get tire of the jobros. l...
# 1200850  yay for everyon who' down with the blog/track ...
# 668476   @hellaelisa i'm in la forth weekend sorri i wi...
#
#                                                    numbers
# 1465654  [False, False, False, False, False, False, Fal...
# 143745   [False, False, False, False, False, False, Fal...
# 1215916                       [False, False, False, False]
# 1481839                       [False, False, False, False]
# 66450    [False, False, False, False, False, False, Fal...
# ...                                                    ...
# 785955   [False, False, False, False, False, False, Fal...
# 339404                 [False, False, False, False, False]
# 418113   [False, False, False, False, False, False, Fal...
# 1200850  [False, False, False, False, False, False, Fal...
# 668476   [False, False, False, False, False, False, Fal...
#
# [16000 rows x 8 columns]

# %%
test_num = new_data.sample(frac=0.1)
train_num = new_data[~new_data.index.isin(test_num.index)]

# %%
words = [w for s in train_num.numbers for w in s]
p_w_estimate = ctr(words)
p_w_total = len(words)

p_w_t_estimate = {}
p_w_t_totals = {}

for l in set(train_num.polarity):
    sub_frame = train_num[train_num.polarity == l]
    sub_words = [w for s in sub_frame.numbers for w in s]
    p_w_t_estimate[l] = ctr(sub_words)
    p_w_t_totals[l] = len(sub_words)

# %%
def PwtN(W, T):
    if W not in p_w_t_estimate[T]: return smoother
    return p_w_t_estimate[T][W] / p_w_t_totals[T]

# %%
def PtwN(T, W):
    return PwtN(W, T) * Pt(T) / Pw(W)

# %%
def Pe(E):
    result = {}
    for p in set(train_num.polarity):
        result[p] = np.prod([PtwN(p, word) for word in E])
    return result

# %%
test_stem['result'] = test_stem.stem.apply(Pe)
test_stem['top'] = test_stem.result.apply(lambda x:max(x, key=x.get))
test_stem
# Out:
#         polarity                                              tweet  \
# 424179       neg  is going to #vote and then drive up to #Bonn ....
# 882724       pos  @Bytorsnowdog haha I guess I'll have to.  I th...
# 1372708      pos  @jonasbrothers http://twitpic.com/6q1om - ooh ...
# 815556       pos  @mpilatow - The consequences of SEO would alwa...
# 770071       neg     @CarlisleRCullen yes but no time for baseball
# ...          ...                                                ...
# 47032        neg  New Dollhouse episode in my line-up, I can't W...
# 905467       pos  @kittyfisher Are they both still talking to yo...
# 117863       neg  Can't find any super-duper nice Twitter app fo...
# 135263       neg  Ugh tired as fuh driving around pines. Tossed ...
# 1250288      pos  @joanvaughan Lol that's a new one! Yay! Steely...
#
#                                                 splittweet  \
# 424179   [is, going, to, #vote, and, then, drive, up, t...
# 882724   [@Bytorsnowdog, haha, I, guess, I'll, have, to...
# 1372708  [@jonasbrothers, http://twitpic.com/6q1om, -, ...
# 815556   [@mpilatow, -, The, consequences, of, SEO, wou...
# 770071   [@CarlisleRCullen, yes, but, no, time, for, ba...
# ...                                                    ...
# 47032    [New, Dollhouse, episode, in, my, line-up,, I,...
# 905467   [@kittyfisher, Are, they, both, still, talking...
# 117863   [Can't, find, any, super-duper, nice, Twitter,...
# 135263   [Ugh, tired, as, fuh, driving, around, pines.,...
# 1250288  [@joanvaughan, Lol, that's, a, new, one!, Yay!...
#
#                                                  lowercase  \
# 424179   [is, going, to, #vote, and, then, drive, up, t...
# 882724   [@bytorsnowdog, haha, i, guess, i'll, have, to...
# 1372708  [@jonasbrothers, http://twitpic.com/6q1om, -, ...
# 815556   [@mpilatow, -, the, consequences, of, seo, wou...
# 770071   [@carlislercullen, yes, but, no, time, for, ba...
# ...                                                    ...
# 47032    [new, dollhouse, episode, in, my, line-up,, i,...
# 905467   [@kittyfisher, are, they, both, still, talking...
# 117863   [can't, find, any, super-duper, nice, twitter,...
# 135263   [ugh, tired, as, fuh, driving, around, pines.,...
# 1250288  [@joanvaughan, lol, that's, a, new, one!, yay!...
#
#                                                    hashtag  \
# 424179   [is, going, to, vote, and, then, drive, up, to...
# 882724   [@Bytorsnowdog, haha, I, guess, I'll, have, to...
# 1372708  [@jonasbrothers, http://twitpic.com/6q1om, -, ...
# 815556   [@mpilatow, -, The, consequences, of, SEO, wou...
# 770071   [@CarlisleRCullen, yes, but, no, time, for, ba...
# ...                                                    ...
# 47032    [New, Dollhouse, episode, in, my, line-up,, I,...
# 905467   [@kittyfisher, Are, they, both, still, talking...
# 117863   [Can't, find, any, super-duper, nice, Twitter,...
# 135263   [Ugh, tired, as, fuh, driving, around, pines.,...
# 1250288  [@joanvaughan, Lol, that's, a, new, one!, Yay!...
#
#                                                       stem  \
# 424179   [is, go, to, #vote, and, then, drive, up, to, ...
# 882724   [@bytorsnowdog, haha, i, guess, i'll, have, to...
# 1372708  [@jonasbroth, http://twitpic.com/6q1om, -, ooh...
# 815556   [@mpilatow, -, the, consequ, of, seo, would, a...
# 770071   [@carlislercullen, ye, but, no, time, for, bas...
# ...                                                    ...
# 47032    [new, dollhous, episod, in, my, line-up,, i, c...
# 905467   [@kittyfish, are, they, both, still, talk, to,...
# 117863   [can't, find, ani, super-dup, nice, twitter, a...
# 135263   [ugh, tire, as, fuh, drive, around, pines., to...
# 1250288  [@joanvaughan, lol, that', a, new, one!, yay!,...
#
#                                                       join  \
# 424179   is go to #vote and then drive up to #bonn ... ...
# 882724   @bytorsnowdog haha i guess i'll have to. i thi...
# 1372708  @jonasbroth http://twitpic.com/6q1om - ooh so ...
# 815556   @mpilatow - the consequ of seo would alway be ...
# 770071         @carlislercullen ye but no time for basebal
# ...                                                    ...
# 47032    new dollhous episod in my line-up, i can't wai...
# 905467    @kittyfish are they both still talk to you then?
# 117863   can't find ani super-dup nice twitter app for ...
# 135263   ugh tire as fuh drive around pines. toss and t...
# 1250288  @joanvaughan lol that' a new one! yay! steely-...
#
#                                                     result  top
# 424179   {'pos': 3.399613537192134e-05, 'neg': 2.737352...  pos
# 882724   {'pos': 1.101301083667076e-06, 'neg': 8.249754...  pos
# 1372708  {'pos': 0.016314426811923282, 'neg': 0.0149600...  pos
# 815556   {'pos': 2.7931655259877207e-07, 'neg': 2.03275...  pos
# 770071   {'pos': 0.008216126613893586, 'neg': 0.0074259...  pos
# ...                                                    ...  ...
# 47032    {'pos': 1.7120831508137052e-05, 'neg': 1.35879...  pos
# 905467   {'pos': 0.0020838081388845054, 'neg': 0.001829...  pos
# 117863   {'pos': 0.0010494289321660024, 'neg': 0.000908...  pos
# 135263   {'pos': 8.622240978959021e-06, 'neg': 6.744890...  pos
# 1250288  {'pos': 0.0002661605222016013, 'neg': 0.000223...  pos
#
# [1600 rows x 9 columns]

# %%
sum(test_stem.polarity == test_stem.top) / len(test_stem)
# Out:
# 0.49375

# %% [markdown]
# I think a way to improve the classifier would be to test the combination of all the @ and # in a tweet. I think this would better the classifier becasue that is a pretty unique combination of all of those specific characters so I think it woud improve the classifier overall especially when possibly identifying harmful tweets attcking someone by not only tagging them but also creating a harmful hashtag.

# %%
new_data['atandtag'] = new_data['splittweet'].apply(lambda x: [i for i in x if i[0] =='@' or i[0] == '#'])
new_data
# Out:
#         polarity                                              tweet  \
# 1465654      pos  @billyraycyrus what part of ireland are/were y...
# 143745       neg    @sarahdessen we still have our winter coats on
# 1215916      pos                          Threadless Tees $5 sale!
# 1481839      pos                           gone swimming with sebs
# 66450        neg    @KimKardashian im at work and im gonna miss it
# ...          ...                                                ...
# 785955       neg  @WAHMBizbuilder Yes  &amp; stand around in the...
# 339404       neg                 why are planetickets so expensive
# 418113       neg  @timothyh2o  btw, i'm getting tire of the jobr...
# 1200850      pos  Yay for everyone who's down with the blog/trac...
# 668476       neg  @hellaelisa I'm in LA forthe weekend sorry  I ...
#
#                                                 splittweet  \
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [Threadless, Tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@KimKardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@WAHMBizbuilder, Yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [Yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, I'm, in, LA, forthe, weekend, so...
#
#                                                  lowercase  \
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [threadless, tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@kimkardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@wahmbizbuilder, yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, i'm, in, la, forthe, weekend, so...
#
#                                                    hashtag  \
# 1465654  [@billyraycyrus, what, part, of, ireland, are/...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                      [Threadless, Tees, $5, sale!]
# 1481839                       [gone, swimming, with, sebs]
# 66450    [@KimKardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@WAHMBizbuilder, Yes, &amp;, stand, around, i...
# 339404             [why, are, planetickets, so, expensive]
# 418113   [@timothyh2o, btw,, i'm, getting, tire, of, th...
# 1200850  [Yay, for, everyone, who's, down, with, the, b...
# 668476   [@hellaelisa, I'm, in, LA, forthe, weekend, so...
#
#                                                       stem  \
# 1465654  [@billyraycyru, what, part, of, ireland, are/w...
# 143745   [@sarahdessen, we, still, have, our, winter, c...
# 1215916                       [threadless, tee, $5, sale!]
# 1481839                            [gone, swim, with, seb]
# 66450    [@kimkardashian, im, at, work, and, im, gonna,...
# ...                                                    ...
# 785955   [@wahmbizbuild, ye, &amp;, stand, around, in, ...
# 339404                 [whi, are, planeticket, so, expens]
# 418113   [@timothyh2o, btw,, i'm, get, tire, of, the, j...
# 1200850  [yay, for, everyon, who', down, with, the, blo...
# 668476   [@hellaelisa, i'm, in, la, forth, weekend, sor...
#
#                                                       join  \
# 1465654  @billyraycyru what part of ireland are/wer you...
# 143745       @sarahdessen we still have our winter coat on
# 1215916                            threadless tee $5 sale!
# 1481839                                 gone swim with seb
# 66450       @kimkardashian im at work and im gonna miss it
# ...                                                    ...
# 785955   @wahmbizbuild ye &amp; stand around in the kit...
# 339404                       whi are planeticket so expens
# 418113   @timothyh2o btw, i'm get tire of the jobros. l...
# 1200850  yay for everyon who' down with the blog/track ...
# 668476   @hellaelisa i'm in la forth weekend sorri i wi...
#
#                                                    numbers           atandtag
# 1465654  [False, False, False, False, False, False, Fal...   [@billyraycyrus]
# 143745   [False, False, False, False, False, False, Fal...     [@sarahdessen]
# 1215916                       [False, False, False, False]                 []
# 1481839                       [False, False, False, False]                 []
# 66450    [False, False, False, False, False, False, Fal...   [@KimKardashian]
# ...                                                    ...                ...
# 785955   [False, False, False, False, False, False, Fal...  [@WAHMBizbuilder]
# 339404                 [False, False, False, False, False]                 []
# 418113   [False, False, False, False, False, False, Fal...      [@timothyh2o]
# 1200850  [False, False, False, False, False, False, Fal...                 []
# 668476   [False, False, False, False, False, False, Fal...      [@hellaelisa]
#
# [16000 rows x 9 columns]

# %%
test_at = new_data.sample(frac=0.1)
train_at = new_data[~new_data.index.isin(test_at.index)]

# %%
words = [w for s in train_at.atandtag for w in s]
p_w_estimate = ctr(words)
p_w_total = len(words)

p_w_t_estimate = {}
p_w_t_totals = {}

for l in set(train_at.polarity):
    sub_frame = train_at[train_at.polarity == l]
    sub_words = [w for s in sub_frame.atandtag for w in s]
    p_w_t_estimate[l] = ctr(sub_words)
    p_w_t_totals[l] = len(sub_words)

# %%
def PwtA(W, T):
    if W not in p_w_t_estimate[T]: return smoother
    return p_w_t_estimate[T][W] / p_w_t_totals[T]

# %%
def PtwA(T, W):
    return PwtA(W, T) * Pt(T) / Pw(W)

# %%
def Pe(E):
    result = {}
    for p in set(train_at.polarity):
        result[p] = np.prod([PtwA(p, word) for word in E])
    return result

# %%
test_at['result'] = test_at.atandtag.apply(Pe)
test_at['top'] = test_at.result.apply(lambda x:max(x, key=x.get))
test_at
# Out:
#         polarity                                              tweet  \
# 719347       neg  Packing for a trip. As exciting as a trip to t...
# 1252432      pos                @farhan Hey thanks for the spoils!
# 226378       neg                                     Feelings suck
# 112435       neg  Eating my free hotel breakfast (better than no...
# 392408       neg    i feel so bad for what ive done last night
# ...          ...                                                ...
# 50979        neg  @GermanKitty iï¿½m good too. i know what you m...
# 247749       neg  @twoname: Aha! I knew the people in the tech b...
# 760819       neg  Tryin 2 learn history..! It just ain't appenin...
# 1574560      pos        @princeofny lol...thanks! my girl got me!!
# 820408       pos  @taaaschi Oh fun  . . Wearing a moustache??? a...
#
#                                                 splittweet  \
# 719347   [Packing, for, a, trip., As, exciting, as, a, ...
# 1252432          [@farhan, Hey, thanks, for, the, spoils!]
# 226378                                    [Feelings, suck]
# 112435   [Eating, my, free, hotel, breakfast, (better, ...
# 392408   [i, feel, so, bad, for, what, ive, done, last,...
# ...                                                    ...
# 50979    [@GermanKitty, iï¿½m, good, too., i, know, wha...
# 247749   [@twoname:, Aha!, I, knew, the, people, in, th...
# 760819   [Tryin, 2, learn, history..!, It, just, ain't,...
# 1574560  [@princeofny, lol...thanks!, my, girl, got, me!!]
# 820408   [@taaaschi, Oh, fun, ., ., Wearing, a, moustac...
#
#                                                  lowercase  \
# 719347   [packing, for, a, trip., as, exciting, as, a, ...
# 1252432          [@farhan, hey, thanks, for, the, spoils!]
# 226378                                    [feelings, suck]
# 112435   [eating, my, free, hotel, breakfast, (better, ...
# 392408   [i, feel, so, bad, for, what, ive, done, last,...
# ...                                                    ...
# 50979    [@germankitty, iï¿½m, good, too., i, know, wha...
# 247749   [@twoname:, aha!, i, knew, the, people, in, th...
# 760819   [tryin, 2, learn, history..!, it, just, ain't,...
# 1574560  [@princeofny, lol...thanks!, my, girl, got, me!!]
# 820408   [@taaaschi, oh, fun, ., ., wearing, a, moustac...
#
#                                                    hashtag  \
# 719347   [Packing, for, a, trip., As, exciting, as, a, ...
# 1252432          [@farhan, Hey, thanks, for, the, spoils!]
# 226378                                    [Feelings, suck]
# 112435   [Eating, my, free, hotel, breakfast, (better, ...
# 392408   [i, feel, so, bad, for, what, ive, done, last,...
# ...                                                    ...
# 50979    [@GermanKitty, iï¿½m, good, too., i, know, wha...
# 247749   [@twoname:, Aha!, I, knew, the, people, in, th...
# 760819   [Tryin, 2, learn, history..!, It, just, ain't,...
# 1574560  [@princeofny, lol...thanks!, my, girl, got, me!!]
# 820408   [@taaaschi, Oh, fun, ., ., Wearing, a, moustac...
#
#                                                       stem  \
# 719347   [pack, for, a, trip., as, excit, as, a, trip, ...
# 1252432           [@farhan, hey, thank, for, the, spoils!]
# 226378                                        [feel, suck]
# 112435   [eat, my, free, hotel, breakfast, (better, tha...
# 392408   [i, feel, so, bad, for, what, ive, done, last,...
# ...                                                    ...
# 50979    [@germankitti, iï¿½m, good, too., i, know, wha...
# 247749   [@twoname:, aha!, i, knew, the, peopl, in, the...
# 760819   [tryin, 2, learn, history..!, it, just, ain't,...
# 1574560  [@princeofni, lol...thanks!, my, girl, got, me!!]
# 820408   [@taaaschi, oh, fun, ., ., wear, a, moustache?...
#
#                                                       join  \
# 719347   pack for a trip. as excit as a trip to the den...
# 1252432                  @farhan hey thank for the spoils!
# 226378                                           feel suck
# 112435   eat my free hotel breakfast (better than nothi...
# 392408          i feel so bad for what ive done last night
# ...                                                    ...
# 50979    @germankitti iï¿½m good too. i know what you m...
# 247749   @twoname: aha! i knew the peopl in the tech bo...
# 760819   tryin 2 learn history..! it just ain't appenin...
# 1574560         @princeofni lol...thanks! my girl got me!!
# 820408   @taaaschi oh fun . . wear a moustache??? aweso...
#
#                                                    numbers        atandtag  \
# 719347   [False, False, False, False, False, False, Fal...              []
# 1252432         [False, False, False, False, False, False]       [@farhan]
# 226378                                      [False, False]              []
# 112435   [False, False, False, False, False, False, Fal...              []
# 392408   [False, False, False, False, False, False, Fal...              []
# ...                                                    ...             ...
# 50979    [False, False, False, False, False, False, Fal...  [@GermanKitty]
# 247749   [False, False, False, False, False, False, Fal...     [@twoname:]
# 760819   [False, False, False, False, False, False, Fal...              []
# 1574560         [False, False, False, False, False, False]   [@princeofny]
# 820408   [False, False, False, False, False, False, Fal...     [@taaaschi]
#
#                                                     result  top
# 719347                            {'pos': 1.0, 'neg': 1.0}  pos
# 1252432  {'pos': 0.5036111111111111, 'neg': 0.496388888...  pos
# 226378                            {'pos': 1.0, 'neg': 1.0}  pos
# 112435                            {'pos': 1.0, 'neg': 1.0}  pos
# 392408                            {'pos': 1.0, 'neg': 1.0}  pos
# ...                                                    ...  ...
# 50979    {'pos': 0.5036111111111111, 'neg': 0.496388888...  pos
# 247749   {'pos': 0.5036111111111111, 'neg': 0.496388888...  pos
# 760819                            {'pos': 1.0, 'neg': 1.0}  pos
# 1574560  {'pos': 0.5036111111111111, 'neg': 0.496388888...  pos
# 820408   {'pos': 0.5036111111111111, 'neg': 0.496388888...  pos
#
# [1600 rows x 11 columns]

# %%
sum(test_stem.polarity == test_stem.top) / len(test_stem)
# Out:
# 0.49375

# %% [markdown]
# I am not really sure if it overall improved my classifier. It obviously lessened in accuracy so I would have to say that it didn't accuratley do it's job.

# %% [markdown]
# # Summary

# %% [markdown]
# ### the baseline (i.e., most common type): (0.5036111111111111, 0.4963888888888889)
# ### classifier accuracy on just the split text: 0.71
# ### classifier accuracy on the lower-cased, split text: 0.7275
# ### classifier accuracy when you lower-case, split the text and remove all hashtags: 0.725625
# ### classifier accuracy when you lower-case, split the text and stem all of the words: 0.49375
# ### open ended: 0.49375
